# %%
print(1+1)
# Out:
# 2

# %%
print(20/3)
# Out:
# 6.666666666666667

# %%
print(20//3)
# Out:
# 6

# %%
print(15%10)
# Out:
# 5

# %%
print(5**3)
# Out:
# 125

# %%
import math
math.sqrt(90)
# Out:
# 9.486832980505138

# %%
zahl1 = float(input("Zahl 1: "))
zahl2 = float(input("Zahl 2: "))

print(zahl1 + zahl2)
# Out:
# 9.0

# %%
inputZahl = int(input("Zahl: "))

if inputZahl % 2 == 0:
    print("Die Zahl ist gerade")
else:
    print("Die Zahl ist ungerade")
# Out:
# Die Zahl ist ungerade

# %%
for i in range(100):
    if i % 2 == 0:
        print(i , "ist gerade")
    else:
        print(i , "ist ungerade")
# Out:
# 0 ist gerade
# 1 ist ungerade
# 2 ist gerade
# 3 ist ungerade
# 4 ist gerade
# 5 ist ungerade
# 6 ist gerade
# 7 ist ungerade
# 8 ist gerade
# 9 ist ungerade
# 10 ist gerade
# 11 ist ungerade
# 12 ist gerade
# 13 ist ungerade
# 14 ist gerade
# 15 ist ungerade
# 16 ist gerade
# 17 ist ungerade
# 18 ist gerade
# 19 ist ungerade
# 20 ist gerade
# 21 ist ungerade
# 22 ist gerade
# 23 ist ungerade
# 24 ist gerade
# 25 ist ungerade
# 26 ist gerade
# 27 ist ungerade
# 28 ist gerade
# 29 ist ungerade
# 30 ist gerade
# 31 ist ungerade
# 32 ist gerade
# 33 ist ungerade
# 34 ist gerade
# 35 ist ungerade
# 36 ist gerade
# 37 ist ungerade
# 38 ist gerade
# 39 ist ungerade
# 40 ist gerade
# 41 ist ungerade
# 42 ist gerade
# 43 ist ungerade
# 44 ist gerade
# 45 ist ungerade
# 46 ist gerade
# 47 ist ungerade
# 48 ist gerade
# 49 ist ungerade
# 50 ist gerade
# 51 ist ungerade
# 52 ist gerade
# 53 ist ungerade
# 54 ist gerade
# 55 ist ungerade
# 56 ist gerade
# 57 ist ungerade
# 58 ist gerade
# ...
