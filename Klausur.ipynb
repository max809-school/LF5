# %%
gehalt = 40000

rest = gehalt % 100

print(rest)
# Out:
# 0

# %%
4+5==9
# Out:
# True

# %%
(5 == 5) and (6 != 2)
# Out:
# True

# %%
zahl = 25

# a) Überprüfung, ob die Zahl zwischen 20 und 30 (inklusive) liegt
if 20 <= zahl <= 30:
    print("Die Zahl liegt zwischen 20 und 30 (inklusive).")

# b) Überprüfung, ob die Zahl nicht zwischen 20 und 30 liegt
if not (20 <= zahl <= 30):
    print("Die Zahl liegt nicht zwischen 20 und 30.")
# Out:
# Die Zahl liegt zwischen 20 und 30 (inklusive).
